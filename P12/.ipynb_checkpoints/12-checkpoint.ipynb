# %%
import pandas as pd

# %%
df = pd.read_csv("adult.csv", names=["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"])

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
contries = df['native-country'].unique()
contrySubsets = {}

for contry in contries:
    subsets[contry] = df[df['native-country'] == contry]

# %%
subsets.keys()
# Out:
# dict_keys([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico', ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland', ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan', ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland', ' Hungary', ' Holand-Netherlands'])

# %%
allSex = df['sex'].unique()
sexSubsets = {}

for sex in allSex:
    sexSubsets[sex] = df[df['sex'] == sex]

# %%
sexSubsets.keys()
# Out:
# dict_keys([' Male', ' Female'])

# %%
allRace = df['race'].unique()
raceSubsets = {}

for race in allRace:
    raceSubsets[race] = df[df['race'] == race]

# %%
raceSubsets.keys()
# Out:
# dict_keys([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'])

# %%
merge1 = pd.concat([raceSubsets[' White'], raceSubsets[' Black'], raceSubsets[' Asian-Pac-Islander'], raceSubsets[' Amer-Indian-Eskimo'], raceSubsets[' Other']])

# %%
merge1
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 5       37            Private  284582        Masters             14
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32075   27                  ?  147638        Masters             14
# 32232   30            Private  215441   Some-college             10
# 32263   27            Private  176761        HS-grad              9
# 32432   36            Private  208068      Preschool              1
# 32544   31            Private  199655        Masters             14
#
#             marital-status          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
merge2 = pd.concat([sexSubsets[' Male'], sexSubsets[' Female']])

# %%
merge2
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32546   37            Private  198216     Assoc-acdm             12
# 32549   43          State-gov  255835   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32558   58            Private  151910        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
sortedDf = df.sort_values(by="age")

# %%
sortedDf
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 12318   17            Private  127366           11th              7
# 6312    17            Private  132755           11th              7
# 30927   17            Private  108470           11th              7
# 12787   17          Local-gov  308901           11th              7
# 25755   17                  ?   47407           11th              7
# ...    ...                ...     ...            ...            ...
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 8963    90                  ?   77053        HS-grad              9
# 10210   90   Self-emp-not-inc  282095   Some-college             10
#
#             marital-status        occupation    relationship  \
# 12318        Never-married             Sales       Own-child
# ...

# %%
transposed = df.T

# %%
transposed
# Out:
#                          0                    1                   2      \
# age                         39                   50                  38
# workclass            State-gov     Self-emp-not-inc             Private
# fnlwgt                   77516                83311              215646
# education            Bachelors            Bachelors             HS-grad
# education-num               13                   13                   9
# marital-status   Never-married   Married-civ-spouse            Divorced
# occupation        Adm-clerical      Exec-managerial   Handlers-cleaners
# relationship     Not-in-family              Husband       Not-in-family
# race                     White                White               White
# sex                       Male                 Male                Male
# capital-gain              2174                    0                   0
# capital-loss                 0                    0                   0
# ...

# %%
df.insert(0, "ids", range(df.shape[0]))

# %%
long = df.melt(id_vars="ids", var_name="Metric", value_name="value")

# %%
long
# Out:
#           ids  Metric   value
# 0           0     age      39
# 1           1     age      50
# 2           2     age      38
# 3           3     age      53
# 4           4     age      28
# ...       ...     ...     ...
# 488410  32556  income   <=50K
# 488411  32557  income    >50K
# 488412  32558  income   <=50K
# 488413  32559  income   <=50K
# 488414  32560  income    >50K
#
# [488415 rows x 3 columns]

# %%
wide = pd.pivot(data=long, index="ids", columns="Metric", values="value")

# %%
wide.columns.name = None

# %%
wide.reset_index(inplace=True)

# %%
wide
# Out:
#          ids age capital-gain capital-loss    education education-num  fnlwgt  \
# 0          0  39         2174            0    Bachelors            13   77516
# 1          1  50            0            0    Bachelors            13   83311
# 2          2  38            0            0      HS-grad             9  215646
# 3          3  53            0            0         11th             7  234721
# 4          4  28            0            0    Bachelors            13  338409
# ...      ...  ..          ...          ...          ...           ...     ...
# 32556  32556  27            0            0   Assoc-acdm            12  257302
# 32557  32557  40            0            0      HS-grad             9  154374
# 32558  32558  58            0            0      HS-grad             9  151910
# 32559  32559  22            0            0      HS-grad             9  201490
# 32560  32560  52        15024            0      HS-grad             9  287927
#
# ...
