# %%
import pandas as pd

# %%
df = pd.read_csv('Iris.csv', names=['sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm', 'class'])

# %%
df
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
class1 = df[df['class'] == 'Iris-setosa']

# %%
class2 = df[df['class'] == 'Iris-versicolor']

# %%
class3 = df[df['class'] == 'Iris-virginica']

# %%
class1
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 1                  4.9                3.0                 1.4
# 2                  4.7                3.2                 1.3
# 3                  4.6                3.1                 1.5
# 4                  5.0                3.6                 1.4
# 5                  5.4                3.9                 1.7
# 6                  4.6                3.4                 1.4
# 7                  5.0                3.4                 1.5
# 8                  4.4                2.9                 1.4
# 9                  4.9                3.1                 1.5
# 10                 5.4                3.7                 1.5
# 11                 4.8                3.4                 1.6
# 12                 4.8                3.0                 1.4
# 13                 4.3                3.0                 1.1
# ...

# %%
class2
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 50                 7.0                3.2                 4.7
# 51                 6.4                3.2                 4.5
# 52                 6.9                3.1                 4.9
# 53                 5.5                2.3                 4.0
# 54                 6.5                2.8                 4.6
# 55                 5.7                2.8                 4.5
# 56                 6.3                3.3                 4.7
# 57                 4.9                2.4                 3.3
# 58                 6.6                2.9                 4.6
# 59                 5.2                2.7                 3.9
# 60                 5.0                2.0                 3.5
# 61                 5.9                3.0                 4.2
# 62                 6.0                2.2                 4.0
# 63                 6.1                2.9                 4.7
# ...

# %%
class3
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 100                 6.3                3.3                 6.0
# 101                 5.8                2.7                 5.1
# 102                 7.1                3.0                 5.9
# 103                 6.3                2.9                 5.6
# 104                 6.5                3.0                 5.8
# 105                 7.6                3.0                 6.6
# 106                 4.9                2.5                 4.5
# 107                 7.3                2.9                 6.3
# 108                 6.7                2.5                 5.8
# 109                 7.2                3.6                 6.1
# 110                 6.5                3.2                 5.1
# 111                 6.4                2.7                 5.3
# 112                 6.8                3.0                 5.5
# 113                 5.7                2.5                 5.0
# ...

# %%
merge1 = pd.concat([class1, class2])

# %%
merge1
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 1                  4.9                3.0                 1.4
# 2                  4.7                3.2                 1.3
# 3                  4.6                3.1                 1.5
# 4                  5.0                3.6                 1.4
# ..                 ...                ...                 ...
# 95                 5.7                3.0                 4.2
# 96                 5.7                2.9                 4.2
# 97                 6.2                2.9                 4.3
# 98                 5.1                2.5                 3.0
# 99                 5.7                2.8                 4.1
#
#     petal width in cm            class
# 0                 0.2      Iris-setosa
# 1                 0.2      Iris-setosa
# 2                 0.2      Iris-setosa
# 3                 0.2      Iris-setosa
# ...

# %%
merge2 = pd.concat([class2, class3])

# %%
merge2
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 50                  7.0                3.2                 4.7
# 51                  6.4                3.2                 4.5
# 52                  6.9                3.1                 4.9
# 53                  5.5                2.3                 4.0
# 54                  6.5                2.8                 4.6
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm            class
# 50                 1.4  Iris-versicolor
# 51                 1.5  Iris-versicolor
# 52                 1.5  Iris-versicolor
# 53                 1.3  Iris-versicolor
# ...

# %%
sortedDf = df.sort_values('petal length in cm')

# %%
sortedDf
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 22                  4.6                3.6                 1.0
# 13                  4.3                3.0                 1.1
# 14                  5.8                4.0                 1.2
# 35                  5.0                3.2                 1.2
# 36                  5.5                3.5                 1.3
# ..                  ...                ...                 ...
# 131                 7.9                3.8                 6.4
# 105                 7.6                3.0                 6.6
# 117                 7.7                3.8                 6.7
# 122                 7.7                2.8                 6.7
# 118                 7.7                2.6                 6.9
#
#      petal width in cm           class
# 22                 0.2     Iris-setosa
# 13                 0.1     Iris-setosa
# 14                 0.2     Iris-setosa
# 35                 0.2     Iris-setosa
# ...

# %%
transposed = df.T

# %%
transposed
# Out:
#                             0            1            2            3    \
# sepal length in cm          5.1          4.9          4.7          4.6
# sepal width in cm           3.5          3.0          3.2          3.1
# petal length in cm          1.4          1.4          1.3          1.5
# petal width in cm           0.2          0.2          0.2          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             4            5            6            7    \
# sepal length in cm          5.0          5.4          4.6          5.0
# sepal width in cm           3.6          3.9          3.4          3.4
# petal length in cm          1.4          1.7          1.4          1.5
# petal width in cm           0.2          0.4          0.3          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             8            9    ...             140  \
# ...

# %%
df.insert(0, 'ids', range(df.shape[0]))

# %%
df
# Out:
#      ids  sepal length in cm  sepal width in cm  petal length in cm  \
# 0      0                 5.1                3.5                 1.4
# 1      1                 4.9                3.0                 1.4
# 2      2                 4.7                3.2                 1.3
# 3      3                 4.6                3.1                 1.5
# 4      4                 5.0                3.6                 1.4
# ..   ...                 ...                ...                 ...
# 145  145                 6.7                3.0                 5.2
# 146  146                 6.3                2.5                 5.0
# 147  147                 6.5                3.0                 5.2
# 148  148                 6.2                3.4                 5.4
# 149  149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# ...

# %%
melted = df.melt(id_vars='ids', var_name='Metric', value_name='value')

# %%
melted
# Out:
#      ids              Metric           value
# 0      0  sepal length in cm             5.1
# 1      1  sepal length in cm             4.9
# 2      2  sepal length in cm             4.7
# 3      3  sepal length in cm             4.6
# 4      4  sepal length in cm             5.0
# ..   ...                 ...             ...
# 745  145               class  Iris-virginica
# 746  146               class  Iris-virginica
# 747  147               class  Iris-virginica
# 748  148               class  Iris-virginica
# 749  149               class  Iris-virginica
#
# [750 rows x 3 columns]

# %%
wide = pd.pivot(data=melted, index='ids', columns='Metric', values='value')
wide.columns.name = None
wide.reset_index(inplace=True)

# %%
wide
# Out:
#      ids           class petal length in cm petal width in cm  \
# 0      0     Iris-setosa                1.4               0.2
# 1      1     Iris-setosa                1.4               0.2
# 2      2     Iris-setosa                1.3               0.2
# 3      3     Iris-setosa                1.5               0.2
# 4      4     Iris-setosa                1.4               0.2
# ..   ...             ...                ...               ...
# 145  145  Iris-virginica                5.2               2.3
# 146  146  Iris-virginica                5.0               1.9
# 147  147  Iris-virginica                5.2               2.0
# 148  148  Iris-virginica                5.4               2.3
# 149  149  Iris-virginica                5.1               1.8
#
#     sepal length in cm sepal width in cm
# 0                  5.1               3.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# ...
